# %%
from pyspark.sql.types import Row
from pyspark.sql import SQLContext, Row
from pyspark.sql.functions import explode
import json
import re
import pandas as pd

# %%
trending = sc.textFile("s3://waltrend/2017/03/*/*/*/")

# %%
def getcost(trends):
    
    try:
        
        trend = json.loads(trends)
        trend = trend.get('items')
        if not trend:
            return
        return [item['name'] for item in trend]
        
    except:
        return

# %%
trend_items = trending.map(lambda x: getcost(x))
trends = trend_items.map(lambda p: Row(name=p))

# %%
schemait = sqlContext.createDataFrame(trends)

# %%
schemait1 = trends.toDF()

# %%
schemait.printSchema()
# Out:
# root
#  |-- name: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
schemait.show()
# Out:
# +--------------------+
# |                name|
# +--------------------+
# |[Xbox One S 500GB...|
# |[Straight Talk Pr...|
# |[Nintendo Switch ...|
# |[RCA Voyager 7" 1...|
# |[RCA Voyager 7" 1...|
# |[Titanfall 2 (Xbo...|
# |[Titanfall 2 (Xbo...|
# +--------------------+

# %%
items = schemait.select(explode(schemait['name']))
items.createOrReplaceTempView("demanded")

# %%
spark.sql("SELECT col,COUNT(*) AS `num` FROM demanded GROUP BY col ORDER BY num DESC").show(20,False)
# Out:
# +-------------------------------------------------------------------------------+---+
# |col                                                                            |num|
# +-------------------------------------------------------------------------------+---+
# |Microsoft Xbox One Wireless Controller, White                                  |7  |
# |Intex Queen 22" DuraBeam High Rise Airbed Mattress with Built-in Pump          |7  |
# |Mainstays Albany Lane 6-Piece Folding Dining Set, Multiple Colors              |7  |
# |Better Homes and Gardens 8-Cube Organizer, Multiple Colors                     |7  |
# |Mainstays Twin Over Twin Wood Bunk Bed, Multiple Finishes                      |7  |
# |Tramontina PrimaWare 18-Piece Nonstick Cookware Set                            |7  |
# |Google Home                                                                    |6  |
# |Spalding NBA 54" Polycarbonate Backboard                                       |6  |
# |Baby Relax Sleigh Toddler Bed                                                  |6  |
# |Canon PIXMA MX490 Wireless Office All-in-One Printer/Copier/Scanner/Fax Machine|6  |
# |Baby Trend Expedition Jogger Stroller, Millennium                              |5  |
# |RCA Voyager 7" 16GB Tablet Android 6.0 (Marshmallow)                           |5  |
# |Kolcraft Pediatric 800 Crib and Toddler Mattress                               |5  |
# |Haier 5.0 cu ft Freezer, White                                                 |4  |
# |Mainstays Student Desk, Multiple Finishes                                      |4  |
# |Call Of Duty Infinite Warfare (PS4)                                            |4  |
# |Weslo Cadence G 5.9i Folding Treadmill, New Model                              |4  |
# |Xbox One S 500GB Console with Minecraft (Xbox One)                             |4  |
# |Evenflo - Convertible High Chair, Dottie Lime                                  |3  |
# |Graco 4Ever All-in-1 Convertible Car Seat, Choose Your Pattern                 |3  |
# +-------------------------------------------------------------------------------+---+
# only showing top 20 rows

# %%
demandDF = spark.sql("SELECT col,COUNT(*) AS `num` FROM demanded GROUP BY col ORDER BY num DESC")

# %%
items_pandas = demandDF.toPandas()

# %%
items_json = items_pandas.set_index('col').T.to_dict('int').get('num')

# %%
from pymongo import MongoClient
import json

client = MongoClient()
db = client.test

# %%
d = {}
for key,value in items_json.items():
    d[key.replace(".","_")] = value

# %%
result = db.item.insert_one(d)

# %%
result.inserted_id
# Out:
# ObjectId('58c14f8653e7bb305df84434')

# %%
cursor = db.item.find().sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23
': 1, u'Playstation 4 Call of Duty Infinite Warfare 500GB (Walmart Exclusive) (White)': 1, u'Moana (Blu-ray 3D + Blu-ray + DVD + Digital HD) (Widescreen)': 2, u'Safety 1st Guide 65 Sport Convertible Car Seat, Choose Your Color': 1, u'Haier 5_0 cu ft Freezer, White': 4, u'Nintendo Switch Gaming Console with Gray Joy-Con': 2, u"Graco Pack 'n Play Playard, Ashford": 2, u'Igloo Portable Countertop Ice Maker': 3, u'FIFA 17 (Xbox One) with Bonus 500 FIFA Ultimate Team Points': 2, u'Madden NFL 17 (Xbox One) with Bonus 500 Madden NFL 17 Ultimate Team Points': 1, u'Straight Talk Apple iPhone 5S 16GB 4G LTE Prepaid Smartphone': 2, u'Tramontina PrimaWare 18-Piece Nonstick Cookware Set': 7, u'Xbox One S 500GB Console with Minecraft (Xbox One)': 4, u'New Nintendo 3DS XL Pikachu Yellow Edition': 2, u'RCA Voyager 7" 16GB Tablet Android 6_0 (Marshmallow)': 5, u'Xbox One Bluetooth Wireless Controller, Black': 2, u'Dream On Me, Twilight 5\u201d 80 Coil Spring Crib And Toddler Bed Mattress, Choose Your Color': 2, u'_id': ObjectId('58c14f8653e7bb305df84434')}

# %% [markdown]
# ## Currency exchange data

# %%
currency = spark.read.json("s3://walcurrency/2017/03/*/*/*/")

# %%
currency.printSchema()
# Out:
# root
#  |-- privacy: string (nullable = true)
#  |-- quotes: struct (nullable = true)
#  |    |-- USDAED: double (nullable = true)
#  |    |-- USDAUD: double (nullable = true)
#  |    |-- USDCAD: double (nullable = true)
#  |    |-- USDCHF: double (nullable = true)
#  |    |-- USDCNY: double (nullable = true)
#  |    |-- USDEUR: double (nullable = true)
#  |    |-- USDGBP: double (nullable = true)
#  |    |-- USDINR: double (nullable = true)
#  |    |-- USDJPY: double (nullable = true)
#  |    |-- USDZAR: double (nullable = true)
#  |-- source: string (nullable = true)
#  |-- success: boolean (nullable = true)
#  |-- terms: string (nullable = true)
#  |-- timestamp: string (nullable = true)

# %%
currency_df = currency.select(currency['timestamp'],currency['quotes.USDAED'],currency['quotes.USDAUD'],currency['quotes.USDCAD'],currency['quotes.USDCHF'],currency['quotes.USDCNY'],currency['quotes.USDEUR'],currency['quotes.USDGBP'],currency['quotes.USDINR'],currency['quotes.USDJPY'],currency['quotes.USDZAR'])

# %%
currency_pandas = currency_df.toPandas()

# %%
currency_pandas
# Out:
#      timestamp    USDAED    USDAUD    USDCAD    USDCHF    USDCNY    USDEUR  \
# 0  2017-Mar-03  3.671984  1.320701  1.338570  1.012799  6.889801  0.951044
# 1  2017-Mar-04  3.672404  1.314904  1.337304  1.007104  6.895304  0.941304
# 2  2017-Mar-05  3.672404  1.314904  1.337304  1.007104  6.895304  0.941304
# 3  2017-Mar-07  3.671994  1.317008  1.340550  1.012440  6.895394  0.945502
# 4  2017-Mar-02  3.672037  1.305102  1.334860  1.009990  6.881797  0.948802
# 5  2017-Mar-08  3.672098  1.316602  1.340790  1.013020  6.899902  0.945899
# 6  2017-Mar-09  3.672296  1.328101  1.349270  1.015030  6.911303  0.948599
# 7  2017-Mar-06  3.671973  1.318804  1.338960  1.008400  6.895302  0.942019
#
#      USDGBP     USDINR      USDJPY     USDZAR
# 0  0.814301  66.759003  114.318001  13.149882
# 1  0.813350  66.749001  114.004997  13.009804
# 2  0.813350  66.749001  114.004997  13.009804
# 3  0.817398  66.649002  113.991997  13.017701
# 4  0.814410  66.699997  114.056999  13.016298
# 5  0.819320  66.613998  113.904999  12.966099
# 6  0.821970  66.753998  114.540001  13.139903
# 7  0.813730  66.749001  113.763991  13.041402

# %% [markdown]
# ## trending items at walmart and their discount rates calculated

# %%
trend_items = spark.read.json("s3://waltrend/2017/03/*/*/*/")

# %%
trend_items.printSchema()
# Out:
# root
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- addToCartUrl: string (nullable = true)
#  |    |    |-- affiliateAddToCartUrl: string (nullable = true)
#  |    |    |-- age: string (nullable = true)
#  |    |    |-- attributes: struct (nullable = true)
#  |    |    |    |-- actualColor: string (nullable = true)
#  |    |    |    |-- finish: string (nullable = true)
#  |    |    |    |-- pattern: string (nullable = true)
#  |    |    |    |-- size: string (nullable = true)
#  |    |    |    |-- theme: string (nullable = true)
#  |    |    |-- availableOnline: boolean (nullable = true)
#  |    |    |-- bestMarketplacePrice: struct (nullable = true)
#  |    |    |    |-- availableOnline: boolean (nullable = true)
#  |    |    |    |-- clearance: boolean (nullable = true)
#  |    |    |    |-- offerType: string (nullable = true)
#  |    |    |    |-- price: double (nullable = true)
#  |    |    |    |-- sellerInfo: string (nullable = true)
#  |    |    |    |-- standardShipRate: double (nullable = true)
#  |    |    |    |-- twoThreeDayShippingRate: double (nullable = true)
#  |    |    |-- brandName: string (nullable = true)
#  |    |    |-- bundle: boolean (nullable = true)
#  |    |    |-- categoryNode: string (nullable = true)
#  |    |    |-- categoryPath: string (nullable = true)
#  |    |    |-- clearance: boolean (nullable = true)
#  |    |    |-- color: string (nullable = true)
#  |    |    |-- customerRating: string (nullable = true)
#  |    |    |-- customerRatingImage: string (nullable = true)
#  |    |    |-- freeShipToStore: boolean (nullable = true)
#  |    |    |-- freeShippingOver50Dollars: boolean (nullable = true)
#  |    |    |-- gender: string (nullable = true)
#  |    |    |-- giftOptions: struct (nullable = true)
#  |    |    |    |-- allowGiftMessage: boolean (nullable = true)
#  |    |    |    |-- allowGiftReceipt: boolean (nullable = true)
#  |    |    |    |-- allowGiftWrap: boolean (nullable = true)
#  |    |    |-- imageEntities: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- entityType: string (nullable = true)
#  |    |    |    |    |-- largeImage: string (nullable = true)
#  |    |    |    |    |-- mediumImage: string (nullable = true)
#  |    |    |    |    |-- thumbnailImage: string (nullable = true)
#  |    |    |-- isTwoDayShippingEligible: boolean (nullable = true)
#  |    |    |-- itemId: long (nullable = true)
#  |    |    |-- largeImage: string (nullable = true)
#  |    |    |-- longDescription: string (nullable = true)
#  |    |    |-- marketplace: boolean (nullable = true)
#  |    |    |-- maxItemsInOrder: long (nullable = true)
#  |    |    |-- mediumImage: string (nullable = true)
#  |    |    |-- modelNumber: string (nullable = true)
#  |    |    |-- msrp: double (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- ninetySevenCentShipping: boolean (nullable = true)
#  |    |    |-- numReviews: long (nullable = true)
#  |    |    |-- offerType: string (nullable = true)
#  |    |    |-- parentItemId: long (nullable = true)
#  |    |    |-- preOrder: boolean (nullable = true)
#  |    |    |-- preOrderShipsOn: string (nullable = true)
#  |    |    |-- productTrackingUrl: string (nullable = true)
#  |    |    |-- productUrl: string (nullable = true)
#  |    |    |-- rollBack: boolean (nullable = true)
#  |    |    |-- salePrice: double (nullable = true)
#  |    |    |-- sellerInfo: string (nullable = true)
#  |    |    |-- shipToStore: boolean (nullable = true)
#  |    |    |-- shortDescription: string (nullable = true)
#  |    |    |-- size: string (nullable = true)
#  |    |    |-- specialBuy: boolean (nullable = true)
#  |    |    |-- standardShipRate: double (nullable = true)
#  |    |    |-- stock: string (nullable = true)
#  |    |    |-- thumbnailImage: string (nullable = true)
#  |    |    |-- upc: string (nullable = true)
#  |    |    |-- variants: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |-- time: long (nullable = true)
#  |-- timestamp: string (nullable = true)

# %%
trend_df = trend_items.select(explode(trend_items['items.name']))

# %%
df1 = trend_items.select(explode(trend_items['items.msrp']))

# %%
df2 = trend_items.select(explode(trend_items['items.salePrice']))

# %%
df3 = trend_items.select(explode(trend_items['items.customerRating']))

# %%
cost_df = trend_df.toPandas()

# %%
cost_df['msrp'] = df1.toPandas()
cost_df['salePrice'] = df2.toPandas()
cost_df['customerRating'] = df3.toPandas()

# %%
cost_df = cost_df.dropna()

# %%
cost_df['discount'] = ((cost_df['msrp'] -  cost_df['salePrice'])/cost_df['msrp'])*100
cost_df
# Out:
#                                                    col    msrp  salePrice  \
# 0    RCA Voyager 7" 16GB Tablet Android 6.0 (Marshm...   59.99      42.95
# 2            Proscan PLDED5069 50" 1080p 60Hz LED HDTV  259.99     249.98
# 6    Canon PIXMA MX490 Wireless Office All-in-One P...   59.97      39.00
# 7                       Haier 5.0 cu ft Freezer, White  169.84     148.00
# 8        Microsoft Xbox One Wireless Controller, White   59.96      39.00
# 9    Intex Queen 22" DuraBeam High Rise Airbed Matt...   74.97      54.99
# 10   Mainstays Albany Lane 6-Piece Folding Dining S...  124.00      87.75
# 11    Kolcraft Pediatric 800 Crib and Toddler Mattress   39.98      39.46
# 12   Graco 4Ever All-in-1 Convertible Car Seat, Cho...  348.40     299.99
# 13                 Call Of Duty Infinite Warfare (PS4)   59.96      25.70
# 16                 Igloo Portable Countertop Ice Maker   99.99      93.00
# 18            Spalding NBA 54" Polycarbonate Backboard  389.00     197.00
# 19        Ingenuity Convertme Swing 2 Seat   Ridgedale   89.99      54.88
# 22                       Baby Relax Sleigh Toddler Bed   69.98      59.00
# 23       Evenflo - Convertible High Chair, Dottie Lime   49.00      34.88
# 24   iView SupraPad with WiFi 7" Touchscreen Tablet...   59.98      35.00
# 26   RCA Voyager 7" 16GB Tablet Android 6.0 (Marshm...   59.99      35.00
# 30   Straight Talk Prepaid Apple iPhone 5S 16GB CDM...  129.00     119.00
# 31                      Haier 5.0 cu ft Freezer, White  169.84     148.00
# 33   Canon PIXMA MX490 Wireless Office All-in-One P...   59.97      39.00
# 34   Xbox One S 500GB Console with Minecraft (Xbox ...  262.47     249.00
# 35       Microsoft Xbox One Wireless Controller, White   59.96      39.00
# 37   Cosco Scenera NEXT Convertible Car Seat, Choos...   44.98      34.88
# 38   Mainstays Albany Lane 6-Piece Folding Dining S...  124.00      87.75
# 39   Intex Queen 22" DuraBeam High Rise Airbed Matt...   74.97      54.99
# 39           4.352  26.650660
# 40           4.301   1.300650
# 41           4.261   0.550275
# 42           4.164  15.690197
# 43           3.718  55.270180
# 44           4.171  49.357326
# ..             ...        ...
# 130          3.933  34.967484
# 132          4.722  34.956638
# 133          4.354  26.650660
# 135          4.252   1.300650
# 136          4.351  29.233871
# 137            4.0  12.020408
# 139          4.172  49.357326
# 141           4.47  18.715831
# 142          4.086   6.990699
# 145          4.644   0.320043
# 146          3.718  58.305537
# 147          4.036   0.375281
# 149          4.813   0.247506
# 150          4.857  33.500334
# 151          3.835  30.055009
# 152          4.625   4.763753
# 156          4.152   3.850148
# 157          3.961   1.617475
# 158          4.722  34.956638
# 160          4.404  22.454424
# 162           4.25   1.300650
# 164          4.351  26.650660
# 165          4.167   1.633878
# 167            4.3  34.956638
# 168          4.269  29.233871
# 169          4.177  49.357326
# 170          4.113  42.484970
# 171          4.476  18.715831
# 172          4.329  29.237113
# 174          4.322  55.777778
#
# [122 rows x 5 columns]

# %% [markdown]
# ## value of the day , most valuable item for the day combining it with the current currency rates and depicting the values

# %%
vod = spark.read.json("s3://walvod/2017/03/*/*/*/")

# %%
vod.printSchema()
# Out:
# root
#  |-- addToCartUrl: string (nullable = true)
#  |-- affiliateAddToCartUrl: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- attributes: struct (nullable = true)
#  |    |-- finish: string (nullable = true)
#  |-- availableOnline: boolean (nullable = true)
#  |-- bestMarketplacePrice: struct (nullable = true)
#  |    |-- availableOnline: boolean (nullable = true)
#  |    |-- clearance: boolean (nullable = true)
#  |    |-- offerType: string (nullable = true)
#  |    |-- price: double (nullable = true)
#  |    |-- sellerInfo: string (nullable = true)
#  |    |-- standardShipRate: double (nullable = true)
#  |    |-- twoThreeDayShippingRate: double (nullable = true)
#  |-- brandName: string (nullable = true)
#  |-- bundle: boolean (nullable = true)
#  |-- categoryNode: string (nullable = true)
#  |-- categoryPath: string (nullable = true)
#  |-- clearance: boolean (nullable = true)
#  |-- color: string (nullable = true)
#  |-- customerRating: string (nullable = true)
#  |-- customerRatingImage: string (nullable = true)
#  |-- freeShipToStore: boolean (nullable = true)
#  |-- freeShippingOver50Dollars: boolean (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- giftOptions: struct (nullable = true)
#  |    |-- allowGiftMessage: boolean (nullable = true)
#  |    |-- allowGiftReceipt: boolean (nullable = true)
#  |    |-- allowGiftWrap: boolean (nullable = true)
#  |-- imageEntities: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- entityType: string (nullable = true)
#  |    |    |-- largeImage: string (nullable = true)
#  |    |    |-- mediumImage: string (nullable = true)
#  |    |    |-- thumbnailImage: string (nullable = true)
#  |-- isTwoDayShippingEligible: boolean (nullable = true)
#  |-- itemId: long (nullable = true)
#  |-- largeImage: string (nullable = true)
#  |-- longDescription: string (nullable = true)
#  |-- marketplace: boolean (nullable = true)
#  |-- mediumImage: string (nullable = true)
#  |-- modelNumber: string (nullable = true)
#  |-- msrp: double (nullable = true)
#  |-- name: string (nullable = true)
#  |-- ninetySevenCentShipping: boolean (nullable = true)
#  |-- numReviews: long (nullable = true)
#  |-- offerType: string (nullable = true)
#  |-- parentItemId: long (nullable = true)
#  |-- preOrder: boolean (nullable = true)
#  |-- productTrackingUrl: string (nullable = true)
#  |-- productUrl: string (nullable = true)
#  |-- rollBack: boolean (nullable = true)
#  |-- salePrice: double (nullable = true)
#  |-- sellerInfo: string (nullable = true)
#  |-- shipToStore: boolean (nullable = true)
#  |-- shortDescription: string (nullable = true)
#  |-- size: string (nullable = true)
#  |-- standardShipRate: double (nullable = true)
#  |-- stock: string (nullable = true)
#  |-- thumbnailImage: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- upc: string (nullable = true)
#  |-- variants: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
vod_df = vod.select(vod['timestamp'],vod['name'],vod['salePrice'])

# %%
vod_pandas = vod_df.toPandas()

# %%
currency_pandas
# Out:
#      timestamp    USDAED    USDAUD    USDCAD    USDCHF    USDCNY    USDEUR  \
# 0  2017-Mar-03  3.671984  1.320701  1.338570  1.012799  6.889801  0.951044
# 1  2017-Mar-04  3.672404  1.314904  1.337304  1.007104  6.895304  0.941304
# 2  2017-Mar-05  3.672404  1.314904  1.337304  1.007104  6.895304  0.941304
# 3  2017-Mar-07  3.671994  1.317008  1.340550  1.012440  6.895394  0.945502
# 4  2017-Mar-02  3.672037  1.305102  1.334860  1.009990  6.881797  0.948802
# 5  2017-Mar-08  3.672098  1.316602  1.340790  1.013020  6.899902  0.945899
# 6  2017-Mar-09  3.672296  1.328101  1.349270  1.015030  6.911303  0.948599
# 7  2017-Mar-06  3.671973  1.318804  1.338960  1.008400  6.895302  0.942019
#
#      USDGBP     USDINR      USDJPY     USDZAR
# 0  0.814301  66.759003  114.318001  13.149882
# 1  0.813350  66.749001  114.004997  13.009804
# 2  0.813350  66.749001  114.004997  13.009804
# 3  0.817398  66.649002  113.991997  13.017701
# 4  0.814410  66.699997  114.056999  13.016298
# 5  0.819320  66.613998  113.904999  12.966099
# 6  0.821970  66.753998  114.540001  13.139903
# 7  0.813730  66.749001  113.763991  13.041402

# %%
vod_pandas
# Out:
#      timestamp                                               name  salePrice
# 0  2017-Mar-05           Bostitch 18-Piece Tic Tac Box, BSA218DGM       7.20
# 1  2017-Mar-09                Knape and Vogt 6' White Closet Pole       9.76
# 2  2017-Mar-04       Stanley Extendable Runner, Corner, 24" x 24"      28.58
# 3  2017-Mar-06                       Dremel 190 High Speed Cutter       3.34
# 4  2017-Mar-08  Vanity Top 2-Arm Guest Towel Holder (Build to ...     148.25
# 5  2017-Mar-03        Bostitch 7" Turbo (Diamond Blade), BSA4712M       9.99
# 6  2017-Mar-07    RotoZip 1/8" GP8 Guidepoint Drywall ZipBit, 8pk      11.18
# 7  2017-Mar-02   Bostitch 12" 6 Tpi Recip Blade, 3-Pack, BSA4804M       6.38

# %%
item_rates = currency_pandas.set_index('timestamp').join(vod_pandas.set_index('timestamp'))

# %%
item_rates
# Out:
#                USDAED    USDAUD    USDCAD    USDCHF    USDCNY    USDEUR  \
# timestamp
# 2017-Mar-03  3.671984  1.320701  1.338570  1.012799  6.889801  0.951044
# 2017-Mar-04  3.672404  1.314904  1.337304  1.007104  6.895304  0.941304
# 2017-Mar-05  3.672404  1.314904  1.337304  1.007104  6.895304  0.941304
# 2017-Mar-07  3.671994  1.317008  1.340550  1.012440  6.895394  0.945502
# 2017-Mar-02  3.672037  1.305102  1.334860  1.009990  6.881797  0.948802
# 2017-Mar-08  3.672098  1.316602  1.340790  1.013020  6.899902  0.945899
# 2017-Mar-09  3.672296  1.328101  1.349270  1.015030  6.911303  0.948599
# 2017-Mar-06  3.671973  1.318804  1.338960  1.008400  6.895302  0.942019
#
#                USDGBP     USDINR      USDJPY     USDZAR  \
# timestamp
# 2017-Mar-03  0.814301  66.759003  114.318001  13.149882
# 2017-Mar-04  0.813350  66.749001  114.004997  13.009804
# 2017-Mar-05  0.813350  66.749001  114.004997  13.009804
# 2017-Mar-07  0.817398  66.649002  113.991997  13.017701
# 2017-Mar-02  0.814410  66.699997  114.056999  13.016298
# 2017-Mar-08  0.819320  66.613998  113.904999  12.966099
# 2017-Mar-09  0.821970  66.753998  114.540001  13.139903
# 2017-Mar-06  0.813730  66.749001  113.763991  13.041402
#
#                                                           name  salePrice
# timestamp
# 2017-Mar-03        Bostitch 7" Turbo (Diamond Blade), BSA4712M       9.99
# 2017-Mar-04       Stanley Extendable Runner, Corner, 24" x 24"      28.58
# 2017-Mar-05           Bostitch 18-Piece Tic Tac Box, BSA218DGM       7.20
# 2017-Mar-07    RotoZip 1/8" GP8 Guidepoint Drywall ZipBit, 8pk      11.18
# 2017-Mar-02   Bostitch 12" 6 Tpi Recip Blade, 3-Pack, BSA4804M       6.38
# 2017-Mar-08  Vanity Top 2-Arm Guest Towel Holder (Build to ...     148.25
# 2017-Mar-09                Knape and Vogt 6' White Closet Pole       9.76
# 2017-Mar-06                       Dremel 190 High Speed Cutter       3.34

# %%
item_rates_final = pd.DataFrame(item_rates['name'])
item_rates_final['value_INR'] =  item_rates['USDINR'] * item_rates['salePrice']
item_rates_final['value_EUR'] =  item_rates['USDEUR'] * item_rates['salePrice']
item_rates_final['value_GBP'] =  item_rates['USDGBP'] * item_rates['salePrice']
item_rates_final['value_JPY'] =  item_rates['USDJPY'] * item_rates['salePrice']
item_rates_final['value_USD'] =  item_rates['salePrice'] 
item_rates_final
# Out:
#                                                           name    value_INR  \
# timestamp
# 2017-Mar-03        Bostitch 7" Turbo (Diamond Blade), BSA4712M   666.922440
# 2017-Mar-04       Stanley Extendable Runner, Corner, 24" x 24"  1907.686449
# 2017-Mar-05           Bostitch 18-Piece Tic Tac Box, BSA218DGM   480.592807
# 2017-Mar-07    RotoZip 1/8" GP8 Guidepoint Drywall ZipBit, 8pk   745.135842
# 2017-Mar-02   Bostitch 12" 6 Tpi Recip Blade, 3-Pack, BSA4804M   425.545981
# 2017-Mar-08  Vanity Top 2-Arm Guest Towel Holder (Build to ...  9875.525203
# 2017-Mar-09                Knape and Vogt 6' White Closet Pole   651.519020
# 2017-Mar-06                       Dremel 190 High Speed Cutter   222.941663
#
#               value_EUR   value_GBP     value_JPY  value_USD
# timestamp
# 2017-Mar-03    9.500930    8.134867   1142.036830       9.99
# 2017-Mar-04   26.902468   23.245543   3258.262814      28.58
# 2017-Mar-05    6.777389    5.856120    820.835978       7.20
# 2017-Mar-07   10.570712    9.138510   1274.430526      11.18
# 2017-Mar-02    6.053357    5.195936    727.683654       6.38
# 2017-Mar-08  140.229527  121.464190  16886.416102     148.25
# 2017-Mar-09    9.258326    8.022427   1117.910410       9.76
# 2017-Mar-06    3.146343    2.717858    379.971730       3.34
